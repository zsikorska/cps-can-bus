# %% [markdown]
# #### Dataset preprocessing

# %%
import numpy as np
import pandas as pd

# %%
names = ['timestamp', 'canId', 'dlc', 'data0', 'data1', 'data2', 'data3', 'data4', 'data5', 'data6', 'data7', 'flag']

sonata_path = 'survival\\dataset\\Sonata'
sonata_data_flooding = pd.read_csv(sonata_path + '\\Flooding_dataset_SONATA.txt', sep=',', names=names)
sonata_data_fuzzy = pd.read_csv(sonata_path + '\\Fuzzy_dataset_SONATA.txt', sep=',', names=names)
sonata_data_malfunction = pd.read_csv(sonata_path + '\\Malfunction_dataset_SONATA.txt', sep=',', names=names)
sonata_data_normal = pd.read_csv(sonata_path + '\\FreeDrivingData_20180323_SONATA.txt', sep=r'[,\s]+', engine='python', names=names)
sonata_data_normal['flag'] = 'R'

soul_path = 'survival\\dataset\\Soul'
soul_data_flooding = pd.read_csv(soul_path + '\\Flooding_dataset_KIA.txt', sep=',', names=names)
soul_data_fuzzy = pd.read_csv(soul_path + '\\Fuzzy_dataset_KIA.txt', sep=',', names=names)
soul_data_malfunction = pd.read_csv(soul_path + '\\Malfunction153_dataset_KIA.txt', sep=',', names=names)
soul_data_normal = pd.read_csv(soul_path + '\\FreeDrivingData_20180112_KIA.txt', sep=r'[,\s]+', engine='python', names=names)
soul_data_normal['flag'] = 'R'

spark_path = 'survival\\dataset\\Spark'
spark_data_flooding = pd.read_csv(spark_path + '\\Flooding_dataset_Spark.txt', sep=',', names=names)
spark_data_fuzzy = pd.read_csv(spark_path + '\\Fuzzy_dataset_Spark.txt', sep=',', names=names)
spark_data_malfunction = pd.read_csv(spark_path + '\\Malfunction18E_dataset_Spark.txt', sep=',', names=names)
spark_data_normal = pd.read_csv(spark_path + '\\FreeDrivingData_20171231_Spark.txt', sep=r'[,\s]+', engine='python', names=names)
spark_data_normal['flag'] = 'R'

print('Sonata Flooding:', sonata_data_flooding.shape)
print('Sonata Fuzzy:', sonata_data_fuzzy.shape)
print('Sonata Malfunction:', sonata_data_malfunction.shape)
print('Sonata Normal:', sonata_data_normal.shape)
print('---------------------------------')

print('Soul Flooding:', soul_data_flooding.shape)
print('Soul Fuzzy:', soul_data_fuzzy.shape)
print('Soul Malfunction:', soul_data_malfunction.shape)
print('Soul Normal:', soul_data_normal.shape)
print('---------------------------------')

print('Spark Flooding:', spark_data_flooding.shape)
print('Spark Fuzzy:', spark_data_fuzzy.shape)
print('Spark Malfunction:', spark_data_malfunction.shape)
print('Spark Normal:', spark_data_normal.shape)
print('---------------------------------')
# Out:
# Sonata Flooding: (149547, 12)
# Sonata Fuzzy: (135670, 12)
# Sonata Malfunction: (132651, 12)
# Sonata Normal: (117173, 12)
# ---------------------------------
# Soul Flooding: (181901, 12)
# Soul Fuzzy: (249990, 12)
# Soul Malfunction: (173436, 12)
# Soul Normal: (192516, 12)
# ---------------------------------
# Spark Flooding: (120570, 12)
# Spark Fuzzy: (65665, 12)
# Spark Malfunction: (79787, 12)
# Spark Normal: (136934, 12)
# ---------------------------------

# %%
sonata_data_flooding['source'] = 'Flooding'
sonata_data_fuzzy['source'] = 'Fuzzy'
sonata_data_malfunction['source'] = 'Malfunction'
sonata_data_normal['source'] = 'Normal'

soul_data_flooding['source'] = 'Flooding'
soul_data_fuzzy['source'] = 'Fuzzy'
soul_data_malfunction['source'] = 'Malfunction'
soul_data_normal['source'] = 'Normal'

spark_data_flooding['source'] = 'Flooding'
spark_data_fuzzy['source'] = 'Fuzzy'
spark_data_malfunction['source'] = 'Malfunction'
spark_data_normal['source'] = 'Normal'

# %%
sonata_data = pd.concat([sonata_data_flooding, sonata_data_fuzzy, sonata_data_malfunction, sonata_data_normal], ignore_index=True)
soul_data = pd.concat([soul_data_flooding, soul_data_fuzzy, soul_data_malfunction, soul_data_normal], ignore_index=True)
spark_data = pd.concat([spark_data_flooding, spark_data_fuzzy, spark_data_malfunction, spark_data_normal], ignore_index=True)

print('Sonata:', sonata_data.shape)
print('Soul:', soul_data.shape)
print('Spark:', spark_data.shape)
# Out:
# Sonata: (535041, 13)
# Soul: (797843, 13)
# Spark: (402956, 13)

# %%
print('Sonata NaN in each column:')
print(sonata_data.isna().sum())
print('---------------------------------')

print('Soul NaN in each column:')
print(soul_data.isna().sum())
print('---------------------------------')

print('Spark NaN in each column:')
print(spark_data.isna().sum())
# Out:
# Sonata NaN in each column:
# timestamp        0
# canId            0
# dlc              0
# data0            0
# data1            0
# data2         1200
# data3         4796
# data4         4796
# data5        10793
# data6        28792
# data7        28792
# flag         21595
# source           0
# dtype: int64
# ---------------------------------
# Soul NaN in each column:
# timestamp        0
# canId            0
# dlc              0
# data0            0
# data1            0
# data2          461
# data3         2641
# data4         6167
# data5        18147
# data6        43277
# data7        43277
# flag         31669
# source           0
# dtype: int64
# ---------------------------------
# Spark NaN in each column:
# timestamp         0
# canId             0
# dlc               0
# data0             0
# data1          2502
# data2         10503
# data3         19069
# data4         35928
# data5         62459
# data6         87679
# data7        137125
# flag         106450
# source            0
# dtype: int64

# %%
spark_data
# Out:
#            timestamp canId  dlc data0 data1 data2 data3 data4 data5 data6  \
# 0       1.513920e+09  04C1    8    00    CC    80    5E    52    08    00
# 1       1.513920e+09  04C7    3    10    00    00     R   NaN   NaN   NaN
# 2       1.513920e+09  01E1    7    00    00    00    00    00    00    00
# 3       1.513920e+09  00C1    8    00    F9    05    41    02    85    8B
# 4       1.513920e+09  00C5    8    03    52    0F    1D    C3    F4    03
# ...              ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 402951  1.513920e+09   232    8    00    00    00    08    00    00    00
# 402952  1.513920e+09   18E    8    00    00    00    69    A6    9A    06
# 402953  1.513920e+09   191    8    06    9A    06    AA    06    9A    00
# 402954  1.513920e+09   0C7    4    00    07    02    20  None  None  None
# 402955  1.513920e+09   0F9    8    00    00    40    00    00    00    00
#
#        data7 flag    source
# 0         00    R  Flooding
# 1        NaN  NaN  Flooding
# 2          R  NaN  Flooding
# 3         91    R  Flooding
# 4         D4    R  Flooding
# ...      ...  ...       ...
# 402951    00    R    Normal
# 402952    9A    R    Normal
# 402953    00    R    Normal
# 402954  None    R    Normal
# 402955    00    R    Normal
#
# [402956 rows x 13 columns]

# %%
for index, row in spark_data.iterrows():
    if pd.isnull(row.loc['flag']):
        for i in range(len(row) - 2, -1, -1):
            if not pd.isnull(row.iloc[i]):
                spark_data.loc[index, 'flag'] = row.iloc[i]
                column_name = spark_data.columns[i]
                spark_data.loc[index, column_name] = np.nan
                break

# %%
spark_data
# Out:
#            timestamp canId  dlc data0 data1 data2 data3 data4 data5 data6  \
# 0       1.513920e+09  04C1    8    00    CC    80    5E    52    08    00
# 1       1.513920e+09  04C7    3    10    00    00   NaN   NaN   NaN   NaN
# 2       1.513920e+09  01E1    7    00    00    00    00    00    00    00
# 3       1.513920e+09  00C1    8    00    F9    05    41    02    85    8B
# 4       1.513920e+09  00C5    8    03    52    0F    1D    C3    F4    03
# ...              ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 402951  1.513920e+09   232    8    00    00    00    08    00    00    00
# 402952  1.513920e+09   18E    8    00    00    00    69    A6    9A    06
# 402953  1.513920e+09   191    8    06    9A    06    AA    06    9A    00
# 402954  1.513920e+09   0C7    4    00    07    02    20  None  None  None
# 402955  1.513920e+09   0F9    8    00    00    40    00    00    00    00
#
#        data7 flag    source
# 0         00    R  Flooding
# 1        NaN    R  Flooding
# 2        NaN    R  Flooding
# 3         91    R  Flooding
# 4         D4    R  Flooding
# ...      ...  ...       ...
# 402951    00    R    Normal
# 402952    9A    R    Normal
# 402953    00    R    Normal
# 402954  None    R    Normal
# 402955    00    R    Normal
#
# [402956 rows x 13 columns]

# %%
for index, row in sonata_data.iterrows():
    if pd.isnull(row.loc['flag']):
        for i in range(len(row) - 2, -1, -1):
            if not pd.isnull(row.iloc[i]):
                sonata_data.loc[index, 'flag'] = row.iloc[i]
                column_name = sonata_data.columns[i]
                sonata_data.loc[index, column_name] = np.nan
                break

# %%
for index, row in soul_data.iterrows():
    if pd.isnull(row.loc['flag']):
        for i in range(len(row) - 2, -1, -1):
            if not pd.isnull(row.iloc[i]):
                soul_data.loc[index, 'flag'] = row.iloc[i]
                column_name = soul_data.columns[i]
                soul_data.loc[index, column_name] = np.nan
                break

# %%
print('Sonata NaN in each column:')
print(sonata_data.isna().sum())
print('---------------------------------')

print('Soul NaN in each column:')
print(soul_data.isna().sum())
print('---------------------------------')

print('Spark NaN in each column:')
print(spark_data.isna().sum())
# Out:
# Sonata NaN in each column:
# timestamp        0
# canId            0
# dlc              0
# data0            0
# data1            0
# data2         4796
# data3         4796
# data4         4796
# data5        28792
# data6        28792
# data7        28792
# flag             0
# source           0
# dtype: int64
# ---------------------------------
# Soul NaN in each column:
# timestamp        0
# canId            0
# dlc              0
# data0            0
# data1            0
# data2         1719
# data3         5154
# data4         8935
# data5        43277
# data6        43277
# data7        43277
# flag             0
# source           0
# dtype: int64
# ---------------------------------
# Spark NaN in each column:
# timestamp         0
# canId             0
# dlc               0
# data0             0
# data1          6691
# data2         16905
# data3         22703
# data4         58126
# data5         69733
# data6        117506
# data7        170051
# flag              0
# source            0
# dtype: int64

# %%
sonata_data = sonata_data.fillna(-1)
soul_data = soul_data.fillna(-1)
spark_data = spark_data.fillna(-1)

# %%
sonata_data.loc[(sonata_data['flag'] == 'T') & (sonata_data['source'] == 'Flooding'), 'flag'] = 'Flooding'
sonata_data.loc[(sonata_data['flag'] == 'T') & (sonata_data['source'] == 'Fuzzy'), 'flag'] = 'Fuzzy'
sonata_data.loc[(sonata_data['flag'] == 'T') & (sonata_data['source'] == 'Malfunction'), 'flag'] = 'Malfunction'
sonata_data.loc[(sonata_data['flag'] == 'R'), 'flag'] = 'Benign'

soul_data.loc[(soul_data['flag'] == 'T') & (soul_data['source'] == 'Flooding'), 'flag'] = 'Flooding'
soul_data.loc[(soul_data['flag'] == 'T') & (soul_data['source'] == 'Fuzzy'), 'flag'] = 'Fuzzy'
soul_data.loc[(soul_data['flag'] == 'T') & (soul_data['source'] == 'Malfunction'), 'flag'] = 'Malfunction'
soul_data.loc[(soul_data['flag'] == 'R'), 'flag'] = 'Benign'

spark_data.loc[(spark_data['flag'] == 'T') & (spark_data['source'] == 'Flooding'), 'flag'] = 'Flooding'
spark_data.loc[(spark_data['flag'] == 'T') & (spark_data['source'] == 'Fuzzy'), 'flag'] = 'Fuzzy'
spark_data.loc[(spark_data['flag'] == 'T') & (spark_data['source'] == 'Malfunction'), 'flag'] = 'Malfunction'
spark_data.loc[(spark_data['flag'] == 'R'), 'flag'] = 'Benign'

# %%
sonata_data = sonata_data.drop(columns=['source'])
soul_data = soul_data.drop(columns=['source'])
spark_data = spark_data.drop(columns=['source'])

# %%
sonata_data
# Out:
#            timestamp canId  dlc data0 data1 data2 data3 data4 data5 data6  \
# 0       1.513920e+09  02C0    8    14    00    00    00    00    00    00
# 1       1.513920e+09  0002    8    00    00    00    00    00    03    0B
# 2       1.513920e+09  0153    8    00    21    10    FF    00    FF    00
# 3       1.513920e+09  043F    8    10    40    60    FF    5A    87    08
# 4       1.513920e+09  0370    8    00    20    00    00    00    00    00
# ...              ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 535036  1.513920e+09  0130    8    07    80    00    FF    1C    80    0C
# 535037  1.513920e+09  0131    8    12    80    00    00    E0    7F    0C
# 535038  1.513920e+09  0140    8    00    00    00    00    0C    20    2C
# 535039  1.513920e+09  02B0    5    FF    7F    00    05    58    -1    -1
# 535040  1.513920e+09  0316    8    45    26    B0    09    26    24    00
#
#        data7    flag
# 0         00  Benign
# 1         11  Benign
# 2         00  Benign
# 3         00  Benign
# 4         00  Benign
# ...      ...     ...
# 535036    C5  Benign
# 535037    2D  Benign
# 535038    6E  Benign
# 535039    -1  Benign
# 535040    7C  Benign
#
# [535041 rows x 12 columns]

# %%
sonata_data.to_csv('sonata_data.csv', index=False)
soul_data.to_csv('soul_data.csv', index=False)
spark_data.to_csv('spark_data.csv', index=False)
